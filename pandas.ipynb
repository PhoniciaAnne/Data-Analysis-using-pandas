# %% [markdown]
# <a href="https://colab.research.google.com/github/PhoniciaAnne/Data-Analysis-using-pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
data = [1,2,3,4]
ans = pd.DataFrame(data)
print(ans)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
data = { "name" : ["abc","def","ghi"] ,
        "age" : [2,3,4] }
ans = pd.DataFrame(data)
print(ans)
print(ans.loc[0])
# Out:
#   name  age
# 0  abc    2
# 1  def    3
# 2  ghi    4
# name    abc
# age       2
# Name: 0, dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-99780365c3d2> in <cell line: 6>()
#       4 print(ans)
#       5 print(ans.loc[0])
# ----> 6 print(file.options.display.max_rows)
#       7
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'options'

# %%
#creating Labels
data = { "name" : ["abc","def","ghi"] ,
        "age" : [2,3,4] }
ans = pd.DataFrame(data,[4,5,6])
print(ans)
# Out:
#   name  age
# 4  abc    2
# 5  def    3
# 6  ghi    4

# %%
from google.colab import files


uploaded  = files.upload()
# Out:
#      <input type="file" id="files-e9bc96fd-c970-4624-a9e6-8ed7791f226a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9bc96fd-c970-4624-a9e6-8ed7791f226a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
file = pd.read_csv('employees.csv')
print(file.to_string())
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus % Senior Management                  Team
# 0        Douglas    Male    8/6/1993        12:42 PM   97308    6.945              True             Marketing
# 1         Thomas    Male   3/31/1996         6:53 AM   61933    4.170              True                   NaN
# 2          Maria  Female   4/23/1993        11:17 AM  130590   11.858             False               Finance
# 3          Jerry    Male    3/4/2005         1:00 PM  138705    9.340              True               Finance
# 4          Larry    Male   1/24/1998         4:47 PM  101004    1.389              True       Client Services
# 5         Dennis    Male   4/18/1987         1:35 AM  115163   10.125             False                 Legal
# 6           Ruby  Female   8/17/1987         4:20 PM   65476   10.012              True               Product
# ...

# %%
print(file.head(10))
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
import pandas as pd
print(pd.options.display.max_rows)
print(file.info())
# Out:
# 60
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    object
#  2   Start Date         764 non-null    object
#  3   Last Login Time    764 non-null    object
#  4   Salary             764 non-null    int64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    object
#  7   Team               764 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 53.7+ KB
# None

# %%
#data cleaning
import pandas as pd
file.dropna(inplace=True)
print(file)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
file.fillna(20,inplace = True)
print(file.to_string())
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus % Senior Management                  Team
# 0        Douglas    Male    8/6/1993        12:42 PM   97308    6.945              True             Marketing
# 2          Maria  Female   4/23/1993        11:17 AM  130590   11.858             False               Finance
# 3          Jerry    Male    3/4/2005         1:00 PM  138705    9.340              True               Finance
# 4          Larry    Male   1/24/1998         4:47 PM  101004    1.389              True       Client Services
# 5         Dennis    Male   4/18/1987         1:35 AM  115163   10.125             False                 Legal
# 6           Ruby  Female   8/17/1987         4:20 PM   65476   10.012              True               Product
# 8         Angela  Female  11/22/2005         6:29 AM   95570   18.523              True           Engineering
# ...

# %%
print(file['Team'])
print(file[file['Senior Management'] == 'True'])
# Out:
# 0                 Marketing
# 2                   Finance
# 3                   Finance
# 4           Client Services
# 5                     Legal
#                ...
# 994               Marketing
# 996                 Finance
# 997                 Product
# 998    Business Development
# 999                   Sales
# Name: Team, Length: 764, dtype: object
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
print(file.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 994    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 764, dtype: bool

# %%
#replace duplicates

import pandas as pd
ans = pd.read_csv("data.csv")
ans.loc[7, 'Duration'] = 45
print(ans)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#to extract multiple values
print(ans[ans ["Maxpulse"].isin([175,145])])
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 1          60    117       145     479.0
# 3          45    109       175     282.4
# 54         30    136       175     238.0
# 165        60    110       145     300.0
# 166        60    115       145     310.2

# %%
ans.index
# Out:
# RangeIndex(start=0, stop=169, step=1)
